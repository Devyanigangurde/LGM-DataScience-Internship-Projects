# %% [markdown]
# <a href="https://colab.research.google.com/github/Devyanigangurde/LGM-DataScience-Internship-Projects/blob/main/Task4-Image_to_Pencil_Sketch_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# read the image

# %%
img = cv2.imread('/content/drive/MyDrive/LGM-Internship/check_3.jpg')
cv2_imshow(img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=318x442>
# -1

# %% [markdown]
# image to Grayscale

# %%
greyscale_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(greyscale_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=318x442>
# -1

# %% [markdown]
# Grayscale into Inverted

# %%
inverted_image = 255 - greyscale_img
cv2_imshow(inverted_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=318x442>
# -1

# %% [markdown]
# Gaussian Blur

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
cv2_imshow(blurred_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=318x442>
# -1

# %% [markdown]
# Blur Image Inverted

# %%
inv_blur_img = 255 - blurred_image
cv2_imshow(inv_blur_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=318x442>
# -1

# %% [markdown]
# Sketched Form

# %%
sketch = cv2.divide(greyscale_img, inv_blur_img, scale=256.0)
cv2_imshow(sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=318x442>
# -1

# %%
cv2_imshow(img)
cv2_imshow(sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=318x442>
# <PIL.Image.Image image mode=L size=318x442>
# -1
